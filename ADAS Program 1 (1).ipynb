# %%
import cv2
import numpy as np
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input, decode_predictions
#load pretrained cnn
model = MobileNetV2(weights = 'imagenet')
#read an image 
image = cv2.imread("day.jpg")
#resize the image 
img = cv2.resize(image,(224,224))
#prepare the image 
x = np.expand_dims(img, axis=0)
x= preprocess_input(x)
#cnn prediction
predictions = model.predict(x)

print(decode_predictions(predictions, top=3)[0])

#simulate brightness calculation
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
brightness = np.mean(gray)
print("Ambient Brightness:" ,brightness)
if brightness<80:
  print("Headlights ON")
else:
  print("Headlights OFF")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# [('n09428293', 'seashore', np.float32(0.33798352)), ('n09246464', 'cliff', np.float32(0.05965433)), ('n09399592', 'promontory', np.float32(0.030617151))]
# Ambient Brightness: 136.66784202749744
# Headlights OFF
